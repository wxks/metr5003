# %%
import sys
print(sys.executable)
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
# Out:
# /Users/katestapleton/mambaforge/envs/metr5003/bin/python
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# NOTE TO SELF: in terminal type "which python" to see envionmental pathway, you can take this pathway to recconect VS Code to the correct environment.
